# %%
import pandas as pd
data=pd.read_csv("train.tsv",sep="\t")
data.head(10)
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
# 5         6           1  of escapades demonstrating the adage that what...
# 6         7           1                                                 of
# 7         8           1  escapades demonstrating the adage that what is...
# 8         9           1                                          escapades
# 9        10           1  demonstrating the adage that what is good for ...
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2
# 5          2
# 6          2
# 7          2
# 8          2
# 9          2

# %%
data["Phrase"]
# Out:
# 0         A series of escapades demonstrating the adage ...
# 1         A series of escapades demonstrating the adage ...
# 2                                                  A series
# 3                                                         A
# 4                                                    series
#                                 ...
# 156055                                            Hearst 's
# 156056                            forced avuncular chortles
# 156057                                   avuncular chortles
# 156058                                            avuncular
# 156059                                             chortles
# Name: Phrase, Length: 156060, dtype: object

# %%
#upper-lowe case transformation
data['Phrase'] = data['Phrase'].apply(lambda x: " ".join(x.lower() for x in x.split()))
#extraxt punctions
data['Phrase'] = data['Phrase'].str.replace('[^\w\s]','')
#stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
sw = stopwords.words('english')
data['Phrase'] = data['Phrase'].apply(lambda x: " ".join(x for x in x.split() if x not in sw))
#delete rares
delete= pd.Series(' '.join(data['Phrase']).split()).value_counts()[-1000:]
data['Phrase'] = data['Phrase'].apply(lambda x: " ".join(x for x in x.split() if x not in delete))
#delete numbers
data['Phrase'] = data['Phrase'].str.replace('\d','')
#lemmi
from nltk.stem import WordNetLemmatizer
#nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
data['Phrase'] = data['Phrase'].apply(lambda x: " ".join([lemmatizer.lemmatize(word) for word in x.split()]))
data['Phrase'].head(10)
# Out:
# C:\Users\USER07\AppData\Local\Temp/ipykernel_12588/3523004241.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Phrase'] = data['Phrase'].str.replace('[^\w\s]','')
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER07\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\USER07\AppData\Local\Temp/ipykernel_12588/3523004241.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Phrase'] = data['Phrase'].str.replace('\d','')
# 0    series demonstrating adage good goose also goo...
# 1                series demonstrating adage good goose
# 2                                               series
# 3
# 4                                               series
# 5                       demonstrating adage good goose
# 6
# 7                       demonstrating adage good goose
# 8
# 9                       demonstrating adage good goose
# Name: Phrase, dtype: object

# %%
x=data['Phrase']

# %%
import timeit

# %%
for line in x.head(10):
    omni_unique_list=list(set(omni_unique_list).union(set(line.split(" "))))

# %%
omni_unique_list=[]
tic=timeit.default_timer()
for line in x.head(10000):
    omni_unique_list=list(set(omni_unique_list).union(set(line.split(" "))))
timeit.default_timer()-tic
# Out:
# 1.2581786999999167

# %%
omni_unique_list=[]
tic=timeit.default_timer()
for line in x.head(20000):
    omni_unique_list=list(set(omni_unique_list).union(set(line.split(" "))))
timeit.default_timer()-tic
# Out:
# 4.373453200000313

# %%
omni_unique_list=[]
tic=timeit.default_timer()
for line in x.head(40000):
    omni_unique_list=list(set(omni_unique_list).union(set(line.split(" "))))
timeit.default_timer()-tic
# Out:
# 15.214122999999745

# %%
omni_unique_list=[]
tic=timeit.default_timer()
for line in x.head(80000):
    omni_unique_list=list(set(omni_unique_list).union(set(line.split(" "))))
timeit.default_timer()-tic
# Out:
# 85.59848590000001

# %%
len(omni_unique_list)
# Out:
# 7799

# %%
omni_unique_list=[]
tic=timeit.default_timer()
for line in x:
    omni_unique_list=list(set(omni_unique_list).union(set(line.split(" "))))
timeit.default_timer()-tic
# Out:
# 214.1499174999999

# %%
# Out:
# 10191

# %%
omni_unique_list
# Out:
# ['',
#  'someone',
#  'surface',
#  'christelle',
#  'puddle',
#  'bracingly',
#  'jockey',
#  'preceded',
#  'loveable',
#  'downtime',
#  'soothe',
#  'allmale',
#  'doc',
#  'acquire',
#  'pop',
#  'meticulously',
#  'rapidfire',
#  'atypically',
#  'agitator',
#  'characterize',
#  'bestowed',
#  'fanboy',
#  'disloyal',
#  'handled',
#  'solution',
#  'tortured',
#  'achievement',
#  'fourstar',
#  'unfamiliar',
#  'shower',
#  'inertia',
#  'explosion',
#  'benefited',
#  'inventiveness',
#  'thesis',
#  'insubstantial',
#  'perform',
#  'cinematography',
#  'lose',
#  'selfreferential',
#  'animal',
#  'progression',
#  'desert',
#  'afterwards',
#  'annesophie',
#  'clothes',
#  'invest',
#  'screenwriting',
#  'orleans',
#  'awful',
#  'rolling',
#  'longtime',
#  'videodvd',
#  'captain',
#  'nouvelle',
#  'updating',
#  'builtin',
#  'avoid',
#  'terminally',
#  'bump',
#  'filled',
#  'singleminded',
#  'plummer',
#  'french',
#  'artifice',
#  'screenful',
#  'addition',
#  'hallucinogenic',
#  'stuttering',
#  'wit',
#  'welled',
#  'personified',
#  'bestial',
#  'greenfingers',
#  'soundtrack',
#  'friend',
#  'mixedup',
#  'cgi',
#  'inherently',
#  'polemical',
#  'psychodrama',
#  'sun',
#  'accountant',
#  'lecter',
#  'codswallop',
#  'bid',
#  'hip',
#  'shanghai',
#  'doyle',
#  'cheese',
#  'stoked',
#  'incomprehensible',
#  'mainstream',
#  'sheridan',
#  'daydream',
#  'exposition',
#  'wildly',
#  'rocket',
#  'base',
#  'selfpromotion',
#  'eloquently',
#  'heightened',
#  'disorientated',
#  'celebrated',
#  'riveted',
#  'wellcharacterized',
#  'pedigree',
#  'labor',
#  'drama',
#  'suspected',
#  'biggername',
#  'jean',
#  'repartee',
#  'boy',
#  'grossly',
#  'cleverest',
#  'devolves',
#  'tryingly',
#  'wig',
#  'nelson',
#  'tub',
#  'truckzilla',
#  'fishy',
#  'churlish',
#  'bloodletting',
#  'five',
#  'work',
#  'david',
#  'innocent',
#  'anxiety',
#  'damagedgoods',
#  'conveying',
#  'intentionally',
#  'walledoff',
#  'closedoff',
#  'nickleby',
#  'ringu',
#  'remind',
#  'apart',
#  'wow',
#  'hey',
#  'volletta',
#  'cadence',
#  'duking',
#  'opaque',
#  'lilia',
#  'meditative',
#  'anomie',
#  'messianic',
#  'disciplined',
#  'needlessly',
#  'impassive',
#  'thanks',
#  'brain',
#  'threat',
#  'shapeless',
#  'forte',
#  'pogue',
#  'funky',
#  'hourandahalf',
#  'disconnect',
#  'one',
#  'idling',
#  'stone',
#  'ron',
#  'cowriter',
#  'misogyny',
#  'peroxide',
#  'perversity',
#  'cathartic',
#  'cutesy',
#  'category',
#  'kline',
#  'dishonesty',
#  'actorliness',
#  'nastier',
#  'step',
#  'rather',
#  'quietly',
#  'geriatric',
#  'aplenty',
#  'quentin',
#  'combination',
#  'transformation',
#  'crumb',
#  'cockney',
#  'geek',
#  'putrid',
#  'nervous',
#  'pollak',
#  'meaty',
#  'recycle',
#  'catcher',
#  'critic',
#  'willing',
#  'reduced',
#  'acumen',
#  'apply',
#  'vast',
#  'tongueincheek',
#  'fourhour',
#  'millennial',
#  'doublepistoled',
#  'mark',
#  'killing',
#  'determine',
#  'sub',
#  'barrymore',
#  'autobiographical',
#  'intense',
#  'charge',
#  'sane',
#  'falling',
#  'agent',
#  'awakens',
#  'regalia',
#  'japan',
#  'tepid',
#  'trope',
#  'synthetic',
#  'nick',
#  'bit',
#  'shrugging',
#  'underground',
#  'perfunctory',
#  'activity',
#  'exit',
#  'moviehouse',
#  'significance',
#  'unknown',
#  'anguished',
#  'drown',
#  'preposterous',
#  'harm',
#  'september',
#  'hamfisted',
#  'wisegirls',
#  'dismiss',
#  'athleticism',
#  'graceful',
#  'comedydrama',
#  'properly',
#  'fart',
#  'humanly',
#  'opera',
#  'held',
#  'characterization',
#  'messenger',
#  'forgivable',
#  'featurelength',
#  'heard',
#  'orgy',
#  'rye',
#  'chatter',
#  'crystal',
#  'rode',
#  'paranoid',
#  'reacting',
#  'showy',
#  'dancing',
#  'equalizer',
#  'peculiar',
#  'surfer',
#  'formal',
#  'liberating',
#  'chanukah',
#  'south',
#  'yesterday',
#  'discussion',
#  'roy',
#  'spike',
#  'traced',
#  'astringent',
#  'chew',
#  'wyman',
#  'ah',
#  'pleasantly',
#  'transforms',
#  'satisfactory',
#  'ashley',
#  'solidly',
#  'bath',
#  'groan',
#  'letting',
#  'promisingly',
#  'jake',
#  'beguiling',
#  'balto',
#  'balance',
#  'vivre',
#  'ideal',
#  'satisfied',
#  'shifting',
#  'textbook',
#  'emperor',
#  'worn',
#  'subcontinent',
#  'teleprompter',
#  'librarian',
#  'victorious',
#  'et',
#  'somber',
#  'pumpkin',
#  'lowwattage',
#  'manages',
#  'tall',
#  'semen',
#  'money',
#  'restored',
#  'amazing',
#  'fare',
#  'finest',
#  'goofball',
#  'subtlety',
#  'skeleton',
#  'disguising',
#  'hairdo',
#  'unpersuasive',
#  'u',
#  'chatty',
#  'behind',
#  'kosashvili',
#  'crucifixion',
#  'reel',
#  'distracting',
#  'extradry',
#  'equilibrium',
#  'lively',
#  'aristocracy',
#  'unexpected',
#  'condition',
#  'liar',
#  'heartfelt',
#  'dawn',
#  'evolved',
#  'gothic',
#  'shake',
#  'freaking',
#  'corrupt',
#  'reconstruction',
#  'relate',
#  'metal',
#  'evenflowing',
#  'came',
#  'short',
#  'tarzan',
#  'mode',
#  'mixing',
#  'flop',
#  'pickup',
#  'sublimely',
#  'fat',
#  'homoeroticism',
#  'glitz',
#  'softporn',
#  'subordinate',
#  'composer',
#  'awkwardly',
#  'trilogy',
#  'similarly',
#  'miraculous',
#  'timid',
#  'character',
#  'reworking',
#  'destiny',
#  'degraded',
#  'embroils',
#  'anticipated',
#  'endurance',
#  'belgium',
#  'selfhatred',
#  'glimpse',
#  'breathtakingly',
#  'propels',
#  'rarest',
#  'folly',
#  'exasperating',
#  'tim',
#  'boast',
#  'respectable',
#  'composed',
#  'er',
#  'roughshod',
#  'awfully',
#  'explored',
#  'quirkiness',
#  'stressreducing',
#  'clare',
#  'trust',
#  'broom',
#  'mario',
#  'adequate',
#  'latesummer',
#  'proper',
#  'row',
#  'adultery',
#  'disney',
#  'thewlis',
#  'inventive',
#  'handsomely',
#  'wary',
#  'smartest',
#  'winking',
#  'summer',
#  'ill',
#  'tidings',
#  'vietnam',
#  'wonderfully',
#  'journalist',
#  'seen',
#  'intact',
#  'savour',
#  'tidal',
#  'bernard',
#  'brainpower',
#  'filmgoing',
#  'holland',
#  'bellydancing',
#  'jagjit',
#  'cleaving',
#  'walk',
#  'tremble',
#  'ramification',
#  'separation',
#  'denizen',
#  'song',
#  'daringly',
#  'personal',
#  'staid',
#  'reminding',
#  'dogma',
#  'pushiness',
#  'chinese',
#  'oneofakind',
#  'thought',
#  'inexcusable',
#  'puberty',
#  'predicament',
#  'kenneth',
#  'failed',
#  'upload',
#  'edward',
#  'quieter',
#  'rudimentary',
#  'uhhh',
#  'pie',
#  'lemon',
#  'think',
#  'awfulness',
#  'spy',
#  'leaky',
#  'raison',
#  'skyscraper',
#  'culprit',
#  'telegram',
#  'writer',
#  'penchant',
#  'tackle',
#  'greene',
#  'behan',
#  'wine',
#  'salute',
#  'clever',
#  'densely',
#  'execution',
#  'puzzle',
#  'humor',
#  'blue',
#  'cutis',
#  'jostling',
#  'urgent',
#  'immediacy',
#  'elm',
#  'ground',
#  'craziness',
#  'nuclear',
#  'fluttering',
#  'civics',
#  'completely',
#  'vertical',
#  'cannon',
#  'notsobright',
#  'developing',
#  'monotony',
#  'hothouse',
#  'lame',
#  'uma',
#  'forbearing',
#  'gathering',
#  'punk',
#  'cliffnotes',
#  'ironically',
#  'ant',
#  'reminds',
#  'diminishing',
#  'spine',
#  'unleashes',
#  'hear',
#  'fire',
#  'criticism',
#  'startling',
#  'stay',
#  'cheeky',
#  'doppelganger',
#  'intellectual',
#  'hungryman',
#  'butter',
#  'ushered',
#  'cheering',
#  'tear',
#  'dover',
#  'golden',
#  'incorporate',
#  'neglecting',
#  'million',
#  'f',
#  'paper',
#  'yiddish',
#  'multiple',
#  'purdy',
#  'neverland',
#  'cleareyed',
#  'subtlest',
#  'factory',
#  'chortle',
#  'proceed',
#  'draw',
#  'reverse',
#  'girlfriend',
#  'preteen',
#  'columbine',
#  'progressed',
#  'populace',
#  'terribly',
#  'culkin',
#  'ripening',
#  'gremlin',
#  'distracted',
#  'uptight',
#  'guessed',
#  'pasolini',
#  'crescendo',
#  'onedimensional',
#  'pacing',
#  'hiding',
#  'humanity',
#  'allegedly',
#  'scathing',
#  'difficult',
#  'beloved',
#  'merely',
#  'knee',
#  'camp',
#  'tightened',
#  'saccharine',
#  'pious',
#  'adjusting',
#  'longing',
#  'lucky',
#  'chiaroscuro',
#  'funny',
#  'expressionistic',
#  'misconstrued',
#  'spinning',
#  'bouquet',
#  'grimace',
#  'nasty',
#  'lawrence',
#  'widescreen',
#  'former',
#  'straining',
#  'rabbitproof',
#  'actress',
#  'bygone',
#  'unqualified',
#  'unearth',
#  'transformed',
#  'dangerously',
#  'hawn',
#  'redone',
#  'bike',
#  'tailor',
#  'based',
#  'investigate',
#  'puritanical',
#  'theweek',
#  'recently',
#  'rank',
#  'curling',
#  'correct',
#  'weil',
#  'signature',
#  'wallace',
#  'prevents',
#  'contains',
#  'cool',
#  'king',
#  'shecute',
#  'trenchant',
#  'gulzar',
#  'schlocky',
#  'younger',
#  'signpost',
#  'gag',
#  'undying',
#  'florid',
#  'switchblade',
#  'norm',
#  'troubled',
#  'reversal',
#  'wonderment',
#  'poster',
#  'ballroom',
#  'nash',
#  'angry',
#  'highoctane',
#  'ignite',
#  'playing',
#  'staged',
#  'dysfunctional',
#  'countercultural',
#  'panic',
#  'eyeball',
#  'crypt',
#  'al',
#  'diego',
#  'opened',
#  'postproduction',
#  'languishing',
#  'unbelievable',
#  'shepard',
#  'curtain',
#  'benshan',
#  'look',
#  'uncertainty',
#  'shrek',
#  'holm',
#  'scrawled',
#  'illusion',
#  'bryan',
#  'maturity',
#  'fondness',
#  'melancholy',
#  'funnier',
#  'abysmal',
#  'modernize',
#  'pinnacle',
#  'grey',
#  'thriller',
#  'career',
#  'poetry',
#  'clearly',
#  'parker',
#  'uncinematic',
#  'massoud',
#  'synagogue',
#  'credit',
#  'plympton',
#  'isolation',
#  'disturbance',
#  'intermediary',
#  'invented',
#  'rip',
#  'ball',
#  'pratfall',
#  'cursory',
#  'inject',
#  'distilled',
#  'cohesive',
#  'halfbaked',
#  'idea',
#  'tension',
#  'box',
#  'jonah',
#  'sounding',
#  'kidsinperil',
#  'ample',
#  'fine',
#  'bollywood',
#  'kinky',
#  'thrown',
#  'orgasm',
#  'da',
#  'prophecy',
#  'arbitrary',
#  'illness',
#  'jumbled',
#  'swing',
#  'lock',
#  'pathos',
#  'dickens',
#  'mountain',
#  'ordinary',
#  'drug',
#  'aggrandizing',
#  'tissuethin',
#  'faith',
#  'gamble',
#  'mysterious',
#  'furious',
#  'affirms',
#  'fanatic',
#  'gun',
#  'reno',
#  'sameness',
#  'tempted',
#  'situation',
#  'lai',
#  'brusqueness',
#  'interested',
#  'paw',
#  'disappointed',
#  'ratliff',
#  'maintains',
#  'whirl',
#  'viewpoint',
#  'pill',
#  'oscar',
#  'passable',
#  'churn',
#  'thinker',
#  'athlete',
#  'relegated',
#  'planet',
#  'creep',
#  'relic',
#  'rape',
#  'offer',
#  'face',
#  'marquis',
#  'regarding',
#  'vardalos',
#  'clerk',
#  'intriguing',
#  'outweighs',
#  'developed',
#  'environmental',
#  'swordfights',
#  'histrionics',
#  'refreshed',
#  'disagree',
#  'luster',
#  'caretaker',
#  'inhabit',
#  'thoroughfare',
#  'kibbitzes',
#  'spite',
#  'gradeschool',
#  'showbiz',
#  'surf',
#  'overall',
#  'rarely',
#  'unwatchable',
#  'response',
#  'sentence',
#  'decency',
#  'overtake',
#  'doublebarreled',
#  'fraction',
#  'fatale',
#  'engaging',
#  'gonna',
#  'lag',
#  'alluring',
#  'surefire',
#  'primitive',
#  'semiamusing',
#  'authority',
#  'debating',
#  'felt',
#  'autocritique',
#  'enter',
#  'slide',
#  'survival',
#  'alfred',
#  'israeli',
#  'gadget',
#  'moodiness',
#  'tattered',
#  'sundrenched',
#  'happy',
#  'hears',
#  'baffling',
#  'djeinaba',
#  'recommending',
#  'joke',
#  'suitably',
#  'forgiveness',
#  'understandable',
#  'evergrowing',
#  'sexy',
#  'malik',
#  'palpable',
#  'bullwinkle',
#  'studioproduced',
#  'damn',
#  'crack',
#  'insight',
#  'dr',
#  'fellow',
#  'caterer',
#  'stasis',
#  'demme',
#  'navigate',
#  'save',
#  'morbid',
#  'spotlight',
#  'forget',
#  'enormous',
#  'scientist',
#  'france',
#  'book',
#  'loathsome',
#  'interference',
#  'elemental',
#  'youthful',
#  'spirited',
#  'discontent',
#  'challenged',
#  'powerfully',
#  'contender',
#  'commercial',
#  'designed',
#  'complex',
#  'begrudge',
#  'diverse',
#  'italic',
#  'trifecta',
#  'pained',
#  'palma',
#  'harvesting',
#  'wayne',
#  'viewer',
#  'kingsley',
#  'overweight',
#  'unexpectedly',
#  'shakespearean',
#  'pungent',
#  'ba',
#  'irish',
#  'delightful',
#  'simmering',
#  'predominantly',
#  'swimming',
#  'cowritten',
#  'duplicate',
#  'normal',
#  'skunk',
#  'zealand',
#  'arrangement',
#  'yellow',
#  'joyous',
#  'vent',
#  'nesbitt',
#  'always',
#  'goodforyou',
#  'charming',
#  'broken',
#  'lunatic',
#  'longest',
#  'irrevocable',
#  'shreve',
#  'violence',
#  'ii',
#  'presiding',
#  'improves',
#  'scooter',
#  'strangling',
#  'hopkinsrock',
#  'hell',
#  'job',
#  'diary',
#  'nationalist',
#  'regurgitates',
#  'hibernation',
#  'gruesome',
#  'biased',
#  'barrel',
#  'fabulousness',
#  'smoothly',
#  'flickering',
#  'bladerunner',
#  'content',
#  'lifestyle',
#  'constraint',
#  'highconcept',
#  'riled',
#  'flinching',
#  'carmen',
#  'unremarkable',
#  'transport',
#  'michelle',
#  'resourceful',
#  'impression',
#  'joyless',
#  'understands',
#  'pauline',
#  'bestknown',
#  'kitchensink',
#  'petri',
#  'kafka',
#  'forcefully',
#  'assurance',
#  'caricature',
#  'darkness',
#  'complain',
#  'seamy',
#  'comingofagecomingout',
#  'defeated',
#  'hijinks',
#  'versatile',
#  'snore',
#  'bite',
#  'blair',
#  'reception',
#  'subtext',
#  'mira',
#  'considers',
#  'filmgoers',
#  'amir',
#  'thumbing',
#  'captured',
#  'stopped',
#  'usual',
#  'reunion',
#  'callar',
#  'pocket',
#  'stark',
#  'stillinestimable',
#  'feeble',
#  'forgets',
#  'minutia',
#  'psychology',
#  'stomach',
#  'glorious',
#  'costner',
#  'lady',
#  'tougher',
#  'arm',
#  'scotland',
#  'gilliam',
#  'mattel',
#  'element',
#  'poor',
#  'litmus',
#  'exiled',
#  'curmudgeon',
#  'farewelltoinnocence',
#  'interesting',
#  'empathizes',
#  'gasp',
#  'evident',
#  'bruce',
#  'digest',
#  'reign',
#  'bad',
#  'kitchen',
#  'history',
#  'expect',
#  'satisfy',
#  'haneke',
#  'drive',
#  'apparently',
#  'playbook',
#  'bold',
#  'wood',
#  'thrill',
#  'perfectly',
#  'gayton',
#  'obscenity',
#  'sustains',
#  'monotone',
#  'screaming',
#  'pact',
#  'dig',
#  'muddle',
#  'boll',
#  'twohourandfifteenminute',
#  'jawdroppingly',
#  'rice',
#  'tasteless',
#  'pleased',
#  'conscience',
#  'goodly',
#  'aptitude',
#  'bielinsky',
#  'fore',
#  'fiction',
#  'workable',
#  'avuncular',
#  'expands',
#  'reaching',
#  'complete',
#  'readily',
#  'objectivity',
#  'rachel',
#  'fluid',
#  'poke',
#  'smallest',
#  'spear',
#  ...]
